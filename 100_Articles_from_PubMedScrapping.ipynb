# %%
# !pip install biopython
# Out:
# Collecting biopython
#   Downloading biopython-1.84-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (12 kB)
# Requirement already satisfied: numpy in /usr/local/lib/python3.10/dist-packages (from biopython) (1.25.2)
# Downloading biopython-1.84-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (3.2 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.2/3.2 MB 22.8 MB/s eta 0:00:00
# Installing collected packages: biopython
# Successfully installed biopython-1.84

# %%
from Bio import Entrez
import pandas as pd
import numpy as np
import random
random.seed(10)

# %%
#Using e-search API to find PubMed search results
def search(query):
    Entrez.email = 'emilyvaitsie@gmail.com'
    handle = Entrez.esearch(db='pubmed',
                            sort='relevance',
                            retmax='100',
                            retmode='xml',
                            term=query)
    results = Entrez.read(handle)
    return results

# %%
#Performing the search with the Mesh terms of Alzheimer Disease
studies = search('bioplastics')
studiesIdList = studies['IdList']
len(studiesIdList)
# Out:
# 100

# %%
#Reducing the number of papers to 20 for better computational performance
studiesIdList = random.sample(studiesIdList, 20)
len(studiesIdList)
# Out:
# 20

# %%
#Using e-fetch to get details from the papers obtained from e-search
def fetch_details(id_list):
    ids = ','.join(id_list)
    Entrez.email = 'emilyvaitsi@gmail.com'
    handle = Entrez.efetch(db='pubmed',
                           retmode='xml',
                           id=ids)
    results = Entrez.read(handle)
    return results

# %%
#Making a DF with article information

title_list= []
abstract_list=[]
journal_list = []
language_list =[]
pubdate_year_list = []
pubdate_month_list = []

studies = fetch_details(studiesIdList)

chunk_size = 100
for chunk_i in range(0, len(studiesIdList), chunk_size):
  chunk = studiesIdList[chunk_i:chunk_i + chunk_size]
  papers = fetch_details(chunk)
  for i, paper in enumerate (papers['PubmedArticle']):
    title_list.append(paper['MedlineCitation']['Article']['ArticleTitle'])
    try:
      abstract_list.append(paper['MedlineCitation']['Article']['Abstract']['AbstractText'][0])
    except:
      abstract_list.append('No Abstract')
    journal_list.append(paper['MedlineCitation']['Article']['Journal']['Title'])
    language_list.append(paper['MedlineCitation']['Article']['Language'][0])
    try:
      pubdate_year_list.append(paper['MedlineCitation']['Article']['Journal']['JournalIssue']['PubDate']['Year'])
    except:
      pubdate_year_list.append('No Data')
    try:
      pubdate_month_list.append(paper['MedlineCitation']['Article']['Journal']['JournalIssue']['PubDate']['Month'])
    except:
      pubdate_month_list.append('No Data')

df = pd.DataFrame(list(zip(
    title_list, abstract_list, journal_list, language_list, pubdate_year_list, pubdate_month_list
    )),
    columns=[
             'Title', 'Abstract', 'Journal', 'Language', 'Year','Month'
             ])
df.shape
# Out:
# (20, 6)

# %%
df.head(10)
# Out:
#                                                Title  \
# 0  Treatment of food waste contaminated by biopla...
# 1  Waste to bioplastics: How close are we to sust...
# 2  Leads and hurdles to sustainable microbial bio...
# 3                                         Editorial.
# 4  The challenges of bioplastics in waste managem...
# 5  Advances in microbial exoenzymes bioengineerin...
# 6   Bacterial polyhydroxyalkanoates: Still fabulous?
# 7  From Soy Waste to Bioplastics: Industrial Proo...
# 8          Biopolymers for Enhanced Health Benefits.
# 9  Production of volatile fatty acids (VFAs) from...
#
#                                             Abstract  \
# 0  The use of Black Soldier Fly (BSF) larvae in t...
# 1  Increased awareness of environmental sustainab...
# 2  Indiscriminate usage, disposal and recalcitran...
# 3                                        No Abstract
# 4                                        No Abstract
# 5  Plastic pollution has become a major global co...
# 6  Bacterial polyhydroxyalkanoates (PHA) are poly...
# 7  The global plastic waste problem is pushing fo...
# 8  The definition of the term biopolymer is often...
# 9  The feasibility of producing volatile fatty ac...
#
#                                              Journal Language  Year Month
# 0                Journal of environmental management      eng  2023   Mar
# 1                  Waste management (New York, N.Y.)      eng  2021   Jan
# 2                                        Chemosphere      eng  2022   Oct
# 3                                  Biomacromolecules      eng  2017   Feb
# 4  Waste management & research : the journal of t...      eng  2023   Aug
# 5                                        Chemosphere      eng  2024   May
# 6                           Microbiological research      eng  2016   Nov
# 7                                  Biomacromolecules      eng  2024   Mar
# 8        International journal of molecular sciences      eng  2023   Nov
# 9                             Bioresource technology      eng  2022   Sep

# %%
#Standardizing months
df['Month'].replace('Jan', '01', inplace=True)
df['Month'].replace('Feb', '02', inplace=True)
df['Month'].replace('Mar', '03', inplace=True)
df['Month'].replace('Apr', '04', inplace=True)
df['Month'].replace('May', '05', inplace=True)
df['Month'].replace('Jun', '06', inplace=True)
df['Month'].replace('Jul', '07', inplace=True)
df['Month'].replace('Aug', '08', inplace=True)
df['Month'].replace('Sep', '09', inplace=True)
df['Month'].replace('Oct', '10', inplace=True)
df['Month'].replace('Nov', '11', inplace=True)
df['Month'].replace('Dec', '12', inplace=True)
df['Month'].replace('No Data', np.nan, inplace=True)

# %%
df.head(10)
# Out:
#                                                Title  \
# 0  Treatment of food waste contaminated by biopla...
# 1  Waste to bioplastics: How close are we to sust...
# 2  Leads and hurdles to sustainable microbial bio...
# 3                                         Editorial.
# 4  The challenges of bioplastics in waste managem...
# 5  Advances in microbial exoenzymes bioengineerin...
# 6   Bacterial polyhydroxyalkanoates: Still fabulous?
# 7  From Soy Waste to Bioplastics: Industrial Proo...
# 8          Biopolymers for Enhanced Health Benefits.
# 9  Production of volatile fatty acids (VFAs) from...
#
#                                             Abstract  \
# 0  The use of Black Soldier Fly (BSF) larvae in t...
# 1  Increased awareness of environmental sustainab...
# 2  Indiscriminate usage, disposal and recalcitran...
# 3                                        No Abstract
# 4                                        No Abstract
# 5  Plastic pollution has become a major global co...
# 6  Bacterial polyhydroxyalkanoates (PHA) are poly...
# 7  The global plastic waste problem is pushing fo...
# 8  The definition of the term biopolymer is often...
# 9  The feasibility of producing volatile fatty ac...
#
#                                              Journal Language  Year Month
# 0                Journal of environmental management      eng  2023    03
# 1                  Waste management (New York, N.Y.)      eng  2021    01
# 2                                        Chemosphere      eng  2022    10
# 3                                  Biomacromolecules      eng  2017    02
# 4  Waste management & research : the journal of t...      eng  2023    08
# 5                                        Chemosphere      eng  2024    05
# 6                           Microbiological research      eng  2016    11
# 7                                  Biomacromolecules      eng  2024    03
# 8        International journal of molecular sciences      eng  2023    11
# 9                             Bioresource technology      eng  2022    09
